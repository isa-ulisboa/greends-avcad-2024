# %% [markdown]
# <a href="https://colab.research.google.com/github/marianadc01/greends-avcad-2024/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mariana Dias Coelho (25605)
#
# Curricular Unit - Practical Machine Learning
#
# MSc in Green Data Science

# %% [markdown]
# **Assignment 4**
#
# 3 minute video + upload to Moodle
#
# What to do:
#
# - Adapt the Perceptron class in Overview notebook to address the two following goals:
#   - output the confusion matrix, using 20% of the data set for validation;
#   - compute also the classification accuracy, precision, recall and F1-score for the solution.

# %% [markdown]
# **Original code from ML_overview_with_examples**

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt # to plot
# Actual labels
y_true = np.array([0, 1, 0, 1, 1, 0, 1, 0, 0, 1])
# Predicted labels
y_pred = np.array([0, 1, 1, 1, 0, 0, 1, 0, 1, 1])
# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)
# Define class labels
classes = ['Zero', 'One']
# Plot confusion matrix
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')
# Fill in confusion matrix with values
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment='center',
             color='white' if cm[i, j] > thresh else 'black')
plt.tight_layout()
plt.show()

# %% [markdown]
# **New code for the assignment**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt # to plot

# Actual labels
y_true = np.array([0, 1, 0, 1, 1, 0, 1, 0, 0, 1])
# Predicted labels
y_pred = np.array([0, 1, 1, 1, 0, 0, 1, 0, 1, 1])

# Split data into training and validation sets (80% training, 20% validation)
X_train, X_val, y_train, y_val = train_test_split(np.arange(len(y_true)), y_true, test_size=0.2, random_state=42)

# Use validation set to compute confusion matrix and metrics
cm = confusion_matrix(y_val, y_pred[X_val])
accuracy = accuracy_score(y_val, y_pred[X_val])
precision = precision_score(y_val, y_pred[X_val])
recall = recall_score(y_val, y_pred[X_val])
f1 = f1_score(y_val, y_pred[X_val])

# Define class labels
classes = ['Zero', 'One']

# Plot confusion matrix
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)
plt.xlabel('Predicted label')
plt.ylabel('True label')

# Fill in confusion matrix with values
thresh = cm.max() / 2.
for i, j in np.ndindex(cm.shape):
    plt.text(j, i, format(cm[i, j], 'd'),
             horizontalalignment='center',
             color='white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.show()

# Output metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.5
# Precision: 0.5
# Recall: 1.0
# F1-score: 0.6666666666666666

# %% [markdown]
# **Changes made to the code:**
#
# Imported necessary modules:
#
# - From sklearn.model_selection import train_test_split to import the train_test_split function for splitting the data into training and validation sets;
# - From sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score to import functions for computing classification metrics;
#
# Split the data into training and validation sets:
# - Use train_test_split to split the indices of the data (np.arange(len(y_true))) into training and validation sets. The test_size=0.2 argument specifies that 20% of the data will be used for validation.
# - Assigned the resulting splits to X_train, X_val, y_train, and y_val.
#
# Used validation set to compute metrics:
# - Changed the calculation of the confusion matrix (cm) to use the validation set (y_val) instead of the entire dataset (y_true).
# - Used y_pred[X_val] to select only the predicted values corresponding to the indices of the validation set.
#
# Computed classification metrics:
# - Calculated accuracy, precision, recall, and F1-score using the validation set (y_val and y_pred[X_val]) and respective functions from sklearn.metrics.
#
# Output the metrics:
# - Added print statements to output the computed metrics (accuracy, precision, recall, and f1) after plotting the confusion matrix
#
# These changes ensure that the code splits the data into training and validation sets, computes the confusion matrix and classification metrics using the validation set, and outputs the results. This approach helps in evaluating the performance of the model on unseen data (validation set) and provides insights into its predictive capabilities.
